# %% [markdown]
# 상관계수 파악

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
survived = pd.read_csv('C:/Users/CPB06GameN/Desktop/PROGRAM/big/2019빅콘테스트_챔피언스리그_데이터_수정/train_label.csv')
payment = pd.read_csv('C:/Users/CPB06GameN/Desktop/PROGRAM/big/2019빅콘테스트_챔피언스리그_데이터_수정/train_payment.csv')
act = pd.read_csv('C:/Users/CPB06GameN/Desktop/PROGRAM/big/2019빅콘테스트_챔피언스리그_데이터_수정/train_activity.csv')
trade = pd.read_csv('C:/Users/CPB06GameN/Desktop/PROGRAM/big/2019빅콘테스트_챔피언스리그_데이터_수정/train_trade.csv')
combat = pd.read_csv('C:/Users/CPB06GameN/Desktop/PROGRAM/big/2019빅콘테스트_챔피언스리그_데이터_수정/train_combat.csv')
pledge = pd.read_csv('C:/Users/CPB06GameN/Desktop/PROGRAM/big/2019빅콘테스트_챔피언스리그_데이터_수정/train_pledge.csv')



survived.head()
payment.head()
payment = payment.sort_values(["acc_id"], ascending=[False])   # 28일간 썼던 돈
# payment[payment['acc_id']==74002].mean()
# survived[survived['acc_id']==74002]

# %%
survived.shape, act.shape, payment.shape, trade.shape, combat.shape, pledge.shape
# Out:
# ((1601834, 17),
#  (40000, 3),
#  (66432, 3),
#  (1849325, 11),
#  (1574671, 13),
#  (1083384, 15))

# %% [markdown]
# #### payment와 survived와의 상관관계

# %%
# survived.set_index('acc_id', inplace=True)
payment1 = payment.groupby(payment.acc_id).sum()
# payment1['acc_id'] = payment1.index
# payment1.reset_index(drop = True)
payment1
# Out:
#         day  amount_spent
# acc_id
# 8        27      1.404644
# 20       43      0.896531
# 21       43      2.695461
# 38       42      6.309749
# 41       28      0.035204
# ...     ...           ...
# 130447   66      3.215308
# 130449   18      0.348521
# 130469   41      0.360255
# 130470   34      1.392909
# 130473  143      2.955971
#
# [23726 rows x 2 columns]

# %%
pd.merge(survived, payment1, on='acc_id', how='outer', left_index=True).corr()
# Out:
#                 survival_time  amount_spent_x       day  amount_spent_y
# survival_time        1.000000       -0.106241  0.090350        0.116470
# amount_spent_x      -0.106241        1.000000  0.049742        0.060252
# day                  0.090350        0.049742  1.000000        0.549384
# amount_spent_y       0.116470        0.060252  0.549384        1.000000

# %% [markdown]
# #### act와 survived와의 상관관계

# %%
act1 = act.groupby(act.acc_id).sum().sort_values(['day'])
act1
act2 = act.groupby(act.char_id).count()
act2.head(20)
# survived.index = survived.acc_id
# Out:
#          day  acc_id  server  playtime  npc_kill  solo_exp  party_exp  \
# char_id
# 2          1       1       1         1         1         1          1
# 3          8       8       8         8         8         8          8
# 5         10      10      10        10        10        10         10
# 7          6       6       6         6         6         6          6
# 9          1       1       1         1         1         1          1
# 13        19      19      19        19        19        19         19
# 14         1       1       1         1         1         1          1
# 15         9       9       9         9         9         9          9
# 17         1       1       1         1         1         1          1
# 19         2       2       2         2         2         2          2
# 22         1       1       1         1         1         1          1
# 23         1       1       1         1         1         1          1
# ...

# %%
pd.concat([survived, act1], axis=1).corr()
# Out:
#                      acc_id  survival_time  amount_spent       day   char_id  \
# acc_id             1.000000      -0.001575      0.005493 -0.003330  0.002043
# survival_time     -0.001575       1.000000     -0.106241 -0.003662  0.000779
# amount_spent       0.005493      -0.106241      1.000000  0.001030 -0.008727
# day               -0.003330      -0.003662      0.001030  1.000000  0.836043
# char_id            0.002043       0.000779     -0.008727  0.836043  1.000000
# playtime          -0.010088      -0.002509     -0.007842  0.136269  0.140473
# npc_kill           0.001300      -0.005937     -0.014662  0.215992  0.207455
# solo_exp           0.009089       0.005230     -0.003937  0.183443  0.142900
# party_exp          0.002773      -0.011227      0.016419  0.031935  0.017260
# quest_exp          0.002391       0.001859     -0.004199  0.202520  0.140693
# rich_monster       0.020019      -0.004289     -0.003589  0.467725  0.408584
# ...

# %%
act_k = act
act_k_char = act_k[['acc_id','char_id']]

acid =[]
length=[]
for acc_id in survived['acc_id']:
    a = act_k_char[act_k_char['acc_id']==acc_id]
    length.append(len(a.groupby(a.char_id)))

# %%
act1['char_num'] = length

# %%
pd.concat([survived, act1], axis=1).corr()
# Out:
#                      acc_id  survival_time  amount_spent       day   char_id  \
# acc_id             1.000000      -0.001575      0.005493 -0.003330  0.002043
# survival_time     -0.001575       1.000000     -0.106241 -0.003662  0.000779
# amount_spent       0.005493      -0.106241      1.000000  0.001030 -0.008727
# day               -0.003330      -0.003662      0.001030  1.000000  0.836043
# char_id            0.002043       0.000779     -0.008727  0.836043  1.000000
# playtime          -0.010088      -0.002509     -0.007842  0.136269  0.140473
# npc_kill           0.001300      -0.005937     -0.014662  0.215992  0.207455
# solo_exp           0.009089       0.005230     -0.003937  0.183443  0.142900
# party_exp          0.002773      -0.011227      0.016419  0.031935  0.017260
# quest_exp          0.002391       0.001859     -0.004199  0.202520  0.140693
# rich_monster       0.020019      -0.004289     -0.003589  0.467725  0.408584
# ...

# %% [markdown]
# #### trade와 survived와의 상관관계

# %%
trade.groupby(trade.source_acc_id).sum().head()
# Out:
#                day  type  source_char_id  target_acc_id  target_char_id  \
# source_acc_id
# 2              486     1         8175930        2333153         6331491
# 6              505     0         6382620        1552083         5098193
# 8               54     7         1372958         454673         1735075
# 13              24     2          673564          55134           59106
# 17             522    33         4529356        3973997         3552391
#
#                item_amount  item_price
# source_acc_id
# 2                 0.311620   10.086512
# 6                 0.000047    0.213249
# 8                 0.093602    0.000000
# 13                0.000303    0.000000
# 17                4.197842    0.000000

# %% [markdown]
# #### combat와 survived와의 상관관계

# %%
combat1 = combat.groupby(combat.acc_id).sum()
pd.merge(survived, combat1, on='acc_id', how='outer', left_index=True).corr()
# Out:
#                      survival_time  amount_spent       day   char_id  \
# survival_time             1.000000     -0.106241  0.255750  0.223665
# amount_spent             -0.106241      1.000000 -0.023778 -0.019963
# day                       0.255750     -0.023778  1.000000  0.834052
# char_id                   0.223665     -0.019963  0.834052  1.000000
# class                     0.185384     -0.018787  0.698122  0.603716
# level                     0.212588     -0.007834  0.818031  0.712646
# pledge_cnt                0.111181      0.023414  0.162964  0.143290
# random_attacker_cnt       0.041769      0.006875  0.087746  0.081566
# random_defender_cnt      -0.019688     -0.023449  0.061928  0.060563
# temp_cnt                  0.046311     -0.004833  0.071820  0.061141
# same_pledge_cnt           0.067221      0.018331  0.116700  0.104208
# etc_cnt                   0.048745      0.001041  0.102334  0.098515
# num_opponent              0.118489      0.021017  0.202759  0.179152
#
# ...

# %% [markdown]
# ####  pledge와 survived와의 상관관계

# %%
pledge1 = pledge.groupby(pledge.acc_id).sum()
pd.merge(survived, pledge1, on='acc_id', how='outer', left_index=True).corr()
# Out:
#                       survival_time  amount_spent       day   char_id  \
# survival_time              1.000000     -0.106241  0.256461  0.214956
# amount_spent              -0.106241      1.000000 -0.033220 -0.025938
# day                        0.256461     -0.033220  1.000000  0.795478
# char_id                    0.214956     -0.025938  0.795478  1.000000
# pledge_id                  0.221154     -0.022396  0.776705  0.635152
# play_char_cnt              0.131342      0.004874  0.529820  0.434775
# combat_char_cnt            0.123898      0.019246  0.396094  0.326575
# pledge_combat_cnt          0.131515      0.032157  0.187196  0.161031
# random_attacker_cnt        0.143503      0.018426  0.274283  0.235575
# random_defender_cnt       -0.003670      0.000379  0.150620  0.129951
# same_pledge_cnt            0.168169      0.027634  0.301277  0.268751
# temp_cnt                   0.158025      0.003907  0.423374  0.349184
# ...
